# %% [markdown]
# # Looking for extreme values

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = None

# %%
daily = pd.read_csv('daily_clean.csv')
details = pd.read_csv('daily_foods_clean.csv')

# %%
details.head()
# Out:
#          date                        item  quantity                    unit  \
# 0  2021-04-01                       Decaf      2.00             full recipe
# 1  2021-04-01                 lemon water      2.00             full recipe
# 2  2021-04-01     Banana Protein Surprise      1.25             full recipe
# 3  2021-04-01  Carrots, Cooked From Fresh      2.50  medium - 6" to 7" long
# 4  2021-04-01     Okra, Cooked from Fresh      1.00             cup, sliced
#
#    calories  Energy  Water  Carbs  Fiber  Net Carbs  Fat  Omega-3  Omega-6  \
# 0     75.28       3     19      5      5          5    2        0        0
# 1     10.56       0     52      1      0          1    0        0        0
# 2    411.86      18      3     36     21         38    2        2        0
# 3     52.50       2      4      5     15          3    0        0        0
# 4     35.20       2      4      3     13          1    0        0        0
#
# ...

# %%
details.shape
# Out:
# (2099, 47)

# %% [markdown]
# ## Extreme Calories in Food Items

# %%
plt.scatter(details.index, details.calories)

# %%
details[details.calories > 1000]
# Out:
#             date                                               item  quantity  \
# 306   2021-04-21                                    Sourdough Bread      11.0
# 525   2021-05-05                                    Sourdough Bread       8.0
# 1983  2021-08-04  Trader Joe's, wrap, spicy lentil, with tahini ...       2.0
# 2028  2021-08-07                                      Rice Cooker 1       1.0
#
#              unit  calories  Energy  Water  Carbs  Fiber  Net Carbs  Fat  \
# 306           cup   1598.29      72      5    121     43        131   17
# 525           cup   1162.39      53      4     89     31         96   12
# 1983         Each   1100.00      52      0     62     67         61   53
# 2028  full recipe   1423.50      67     19     73    127         65   67
#
#       Omega-3  Omega-6  Protein  Cystine  Histidine  Isoleucine  Leucine  \
# 306        23       33       45      180        110         143      119
# ...

# %%
daily[daily.date=='2021-04-21']
# Out:
#           date  weight  total_calories  Carbs  Fiber  Net Carbs  Fat  Omega-3  \
# 20  2021-04-21   206.6          2572.4    162     87        172   58      146
#
#     Omega-6  Protein  Cystine  Histidine  Isoleucine  Leucine  Lysine  \
# 20       34       74      199        127         169      138      71
#
#     Methionine  Phenylalanine  Threonine  Tryptophan  Tyrosine  Valine  \
# 20         136            247        124         202       104     156
#
#     B1 (Thiamine)  B2 (Riboflavin)  B3 (Niacin)  B5 (Pantothenic Acid)  \
# 20            409              268          216                     82
#
#     B6 (Pyridoxine)  B12 (Cobalamin)  Folate  Vitamin A  Vitamin C  Vitamin D  \
# 20               84                3     365         79        326          0
#
#     Vitamin E  Vitamin K  Calcium  Copper  Iron  Magnesium  Manganese  \
# 20         29        574       94     173   405        101        258
#
# ...

# %% [markdown]
# Oh my! That was a rough day with 2572 calories. Moral of the story, if you are trying to lose weight you may have to temporarily pause on foods you love :(

# %% [markdown]
# ## Extremely high or low calorie days

# %%
daily.head()
# Out:
#          date  weight  total_calories  Carbs  Fiber  Net Carbs  Fat  Omega-3  \
# 0  2021-04-01   212.2          1941.8    133    144        131   41      201
# 1  2021-04-02   211.2          1934.9    126    211        115   34      260
# 2  2021-04-03   210.8          2059.2    131    142        129   48      187
# 3  2021-04-04   211.2          1924.4    140    258        124   19       84
# 4  2021-04-05   209.4          2216.6    164    233        154   36       93
#
#    Omega-6  Protein  Cystine  Histidine  Isoleucine  Leucine  Lysine  \
# 0       45       50       66        100         129       92      78
# 1       42       58       81        130         139      107      95
# 2       81       61       37        138         168      125      91
# 3       11       57       68        132         145      117     107
# 4       14       55       60        111         116       91      88
#
#    Methionine  Phenylalanine  Threonine  Tryptophan  Tyrosine  Valine  \
# ...

# %%
daily.shape
# Out:
# (133, 44)

# %%
plt.scatter(daily.index, daily.total_calories)

# %%
daily[daily.total_calories < 1000]
# Out:
#           date  weight  total_calories  Carbs  Fiber  Net Carbs  Fat  Omega-3  \
# 66  2021-06-06   200.2           360.2     36     38         36    1        6
# 69  2021-06-09   198.8           311.5     22     52         18    3       31
#
#     Omega-6  Protein  Cystine  Histidine  Isoleucine  Leucine  Lysine  \
# 66        1        3        5         26           8        8       7
# 69        2       15       23         45          54       43      41
#
#     Methionine  Phenylalanine  Threonine  Tryptophan  Tyrosine  Valine  \
# 66           6             15          7          10         4      11
# 69          33             75         47          55        32      49
#
#     B1 (Thiamine)  B2 (Riboflavin)  B3 (Niacin)  B5 (Pantothenic Acid)  \
# 66             16               23           16                     28
# 69             15               13            7                     10
#
#     B6 (Pyridoxine)  B12 (Cobalamin)  Folate  Vitamin A  Vitamin C  Vitamin D  \
# ...

# %%
details[details.date.isin(['2021-06-06', '2021-06-09'])]
# Out:
#             date                          item  quantity  \
# 1017  2021-06-06                  Bananas, Raw       3.0
# 1018  2021-06-06                  Oranges, Raw       1.0
# 1053  2021-06-09                   lemon water       1.0
# 1054  2021-06-09  Pinto Beans, Canned, Drained       1.5
# 1055  2021-06-09                  Spinach, Raw       2.0
#
#                             unit  calories  Energy  Water  Carbs  Fiber  \
# 1017  medium - 7" to 7 7/8" long    315.06      16      9     36     38
# 1018     small - 2 3/8" diameter     45.12      16      9     36     38
# 1053                 full recipe      5.28      14     33     22     52
# 1054           cup, whole pieces    292.41      14     33     22     52
# 1055             cup, cut pieces     13.80      14     33     22     52
#
#       Net Carbs  Fat  Omega-3  Omega-6  Protein  Cystine  Histidine  \
# 1017         36    1        6        1        3        5         26
# ...

# %% [markdown]
# I had trouble loading the food details for these two dates for some reason. Will drop them from the final data

# %%
daily = daily[~daily.date.isin(['2021-06-06', '2021-06-09'])]
daily.shape
# Out:
# (131, 44)

# %%
details = details[~details.date.isin(['2021-06-06', '2021-06-09'])]
details.shape
# Out:
# (2094, 47)

# %%
daily.to_csv('daily_final.csv', index=None)
details.to_csv('daily_foods_final.csv', index=None)

# %% [markdown]
# Now we are ready for some Exploratory Data Analysis!
